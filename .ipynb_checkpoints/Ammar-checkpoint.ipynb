# %%
import pandas as pd
import os

# %%
all_data = pd.read_csv("ammar_19.csv")

all_data.head()
# Out:
#    id_mitra  invoices       nama_drop        kabupaten          propinsi  \
# 0      1398  0101F7FD            Nita           Bekasi        Jawa Barat
# 1      1393  0101LBDC  NAZNIA GALLERY  Jakarta Selatan       DKI Jakarta
# 2      1393  0201D90C  NAZNIA GALLERY    Jakarta Timur       DKI Jakarta
# 3      1773  0201K3GA  Azalia_Elhijab      Tulungagung        Jawa Timur
# 4      1960  020167JK         Aisyiah          Tarakan  Kalimantan Utara
#
#   tgl_checkout    jam      bln   thn  jml_pcs  total_harga  total_diskon  \
# 0     2019/1/1  12:20  January  2019        1        95000             0
# 1     2019/1/1  21:10  January  2019        3       240000             0
# 2     2019/1/2  05:49  January  2019        1        55000             0
# 3     2019/1/2  07:28  January  2019        7       675000             0
# 4     2019/1/2  07:33  January  2019        2       190000             0
#
#    ongkir  total_bayar
# 0   10000        86000
# 1   15000       171000
# 2    9000        44750
# 3   28000       433000
# 4   34000       186000

# %%
import numpy as np
import datetime

all_data['month'] = pd.DatetimeIndex(all_data['tgl_checkout']).month

all_data.head()
# Out:
#    id_mitra  invoices       nama_drop        kabupaten          propinsi  \
# 0      1398  0101F7FD            Nita           Bekasi        Jawa Barat
# 1      1393  0101LBDC  NAZNIA GALLERY  Jakarta Selatan       DKI Jakarta
# 2      1393  0201D90C  NAZNIA GALLERY    Jakarta Timur       DKI Jakarta
# 3      1773  0201K3GA  Azalia_Elhijab      Tulungagung        Jawa Timur
# 4      1960  020167JK         Aisyiah          Tarakan  Kalimantan Utara
#
#   tgl_checkout    jam      bln   thn  jml_pcs  total_harga  total_diskon  \
# 0     2019/1/1  12:20  January  2019        1        95000             0
# 1     2019/1/1  21:10  January  2019        3       240000             0
# 2     2019/1/2  05:49  January  2019        1        55000             0
# 3     2019/1/2  07:28  January  2019        7       675000             0
# 4     2019/1/2  07:33  January  2019        2       190000             0
#
#    ongkir  total_bayar  month
# 0   10000        86000      1
# 1   15000       171000      1
# 2    9000        44750      1
# 3   28000       433000      1
# 4   34000       186000      1

# %%
results_month = all_data.groupby('month').sum()

top5 = results_month.drop(columns=['id_mitra', 'thn'])
top5.head()
# Out:
#        jml_pcs  total_harga  total_diskon      ongkir  total_bayar
# month
# 1         2208    193925000             0     9081000    140557000
# 2         2266    219790000             0     9022500    156903500
# 3         2636    270840000      37525250  2158723147   2332798647
# 4         9956   1025251000     356956300    45473494    712921694
# 5        12602   1714314001     617462850    89679234   1185423884

# %%
import matplotlib.pyplot as plt
import calendar

months = range(1,13)

plt.bar(months, results_month['total_bayar'])
plt.xticks(months, calendar.month_name[1:13], rotation=20)
plt.ylabel('Penjualan')
plt.xlabel('Month number')
plt.show()

# %%
results_kab = all_data.groupby('kabupaten').sum()

results_top5 = all_data.groupby('kabupaten').sum().nlargest(5,'total_bayar')
results_top5

top5 = results_top5.drop(columns=['id_mitra', 'thn','month'])
top5.head()
# Out:
#                    jml_pcs  total_harga  total_diskon    ongkir  total_bayar
# kabupaten
# Bandung               3149    821663000     273054450  19738000    521680300
# Bekasi                1310    236880000      68170750   9855000    164677500
# Jakarta Pusat          412    143305000      36905000   3212000    103375250
# Depok                  679    146120000      44716250   5723000     97321750
# Bogor                  759    131300000      37445250   6084000     92101500
# Jakarta Barat          571    116990000      35756000   3582000     78146500
# Tangerang              556    105600000      33395750   4930000     74156750
# Jakarta Timur          529     98745000      31645250   4509000     69730250
# Jember                 172     92975000      36398750   5282000     61270250
# Jakarta Selatan        443     87265000      28830750   3622000     59863500
# Makassar               308     78690000      22896750   7290000     57545500
# Jakarta Utara          375     71400000      17208250   2531000     50829000
# Tangerang Selatan      356     68770000      23253500   3176000     47108250
# Sidoarjo               360     53880000      11099000   2830000     38130500
# Balikpapan             295     47765000      11500000   4887000     36343250
# Cilegon                393     52765000      18888000   1213000     34031000
# Malang                 240     38505000      10484500   2428000     27472000
# Jayapura               209     32460000       8057750   4099000     25578750
# Cilacap                136     31925000       8217750   1669500     24049250
# Surabaya               176     33350000       8984250   2343000     23574000

# %%
import matplotlib.pyplot as plt

#kabupaten = range(1,21)

kab = [kabupaten for kabupaten, df in top5.groupby('kabupaten')]

plt.bar(kab, top5['total_bayar'])
plt.xticks(kab)
plt.ylabel('Penjualan')
plt.xlabel('Kabupaten')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(30, 6), dpi=200, facecolor='w', edgecolor='k')

cities = [city for city, df in all_data.groupby('kabupaten')]

plt.bar(cities, results_kab['total_bayar'])
plt.xticks(cities, rotation = 'vertical', size = 8)
plt.ylabel('Penjualan dalam M')
plt.xlabel('Nama Kab')
plt.show()

# %%
results_prop = all_data.groupby('propinsi').sum()

results_top5 = all_data.groupby('propinsi').sum().nlargest(5,'total_bayar')

top5 = results_top5.drop(columns=['id_mitra', 'thn', 'Hour', 'Minute', 'Count', 'month'])
top5.head()
# Out:
#              jml_pcs  total_harga  total_diskon    ongkir  total_bayar
# propinsi
# Jawa Barat      7414   1602078001     494178700  54619000   1067479800
# DKI Jakarta     2338    518405000     150345250  17474000    362522500
# Jawa Timur      1436    307410000      90871250  20827000    217015750
# Banten          1455    252805000      84316250  11123500    173322250
# Jawa Tengah      964    193865000      54380750  12173000    137079000

# %%
props = [prop for prop, df in all_data.groupby('propinsi')]

plt.bar(props, results_prop['total_bayar'])
plt.xticks(props, rotation = 'vertical', size = 8)
plt.ylabel('Penjualan dalam M')
plt.xlabel('Nama Prop')
plt.show()

# %%
all_data['Hour'] = pd.to_datetime(all_data['jam']).dt.hour
all_data['Minute'] = pd.to_datetime(all_data['jam']).dt.minute
all_data['Count'] = 1
all_data.head()
# Out:
#    id_mitra  invoices       nama_drop        kabupaten          propinsi  \
# 0      1398  0101F7FD            Nita           Bekasi        Jawa Barat
# 1      1393  0101LBDC  NAZNIA GALLERY  Jakarta Selatan       DKI Jakarta
# 2      1393  0201D90C  NAZNIA GALLERY    Jakarta Timur       DKI Jakarta
# 3      1773  0201K3GA  Azalia_Elhijab      Tulungagung        Jawa Timur
# 4      1960  020167JK         Aisyiah          Tarakan  Kalimantan Utara
#
#   tgl_checkout    jam      bln   thn  jml_pcs  total_harga  total_diskon  \
# 0     2019/1/1  12:20  January  2019        1        95000             0
# 1     2019/1/1  21:10  January  2019        3       240000             0
# 2     2019/1/2  05:49  January  2019        1        55000             0
# 3     2019/1/2  07:28  January  2019        7       675000             0
# 4     2019/1/2  07:33  January  2019        2       190000             0
#
#    ongkir  total_bayar  month  Hour  Minute  Count
# 0   10000        86000      1    12      20      1
# 1   15000       171000      1    21      10      1
# 2    9000        44750      1     5      49      1
# 3   28000       433000      1     7      28      1
# 4   34000       186000      1     7      33      1

# %%
keys = [pair for pair, df in all_data.groupby(['Hour'])]

plt.plot(keys, all_data.groupby(['Hour']).count()['Count'])
plt.xticks(keys)
plt.grid()
plt.show()

# Penjualan tertinggi yaitu di jam 9-10 dan 13. Jika penayangan iklan dilakukan jam 8-9 dan jam 12 akan menghasilkan lebih banyak penjualan.

# %%
df = all_data[all_data['invoices'].duplicated(keep=False)]

df.head()
# Out:
#        id_mitra    invoices nama_drop      kabupaten     propinsi  \
# 17098         1  3010199FI0  rifca AD            NaN          NaN
# 17126      2618  3010199FI0     Renna  Jakarta Barat  DKI Jakarta
#
#       tgl_checkout    jam      bln   thn  jml_pcs  total_harga  total_diskon  \
# 17098   2019/10/30  11:54  October  2019       13      1340000        402000
# 17126   2019/10/30  20:14  October  2019        1        85000         29750
#
#        ongkir  total_bayar  month
# 17098  160000      1098000     10
# 17126    5000        60250     10

# %%
all_data2 = pd.read_csv("ammar_2019_detail.csv")
all_data2.head()
# Out:
#       id  id_produk  invoices       kategori   kode  \
# 0  11131        234  0101F7FD  muslim heroes  MH 03
# 1  11132        258  0101LBDC         raglan   AR31
# 2  11133         49  0101LBDC        t-shirt   AT24
# 3  11134        243  0101LBDC         raglan   AR28
# 4  11135        201  0201D90C        t-shirt   AT64
#
#                       nama_produk ukuran  harga  harga_diskon  harga_profit  \
# 0  SHALAHUDDIN AL-AYYUBI (l/xl) (     xl  95000         76000             0
# 1              IBUMU  (m/l) (m/l)      l  80000         52000             0
# 2             MUSLIM HABITS (m/l)      l  80000         52000             0
# 3         PRINCESS MUSLIMAH (m/l)      l  80000         52000             0
# 4       Pray before flight (xs/s)      s  55000         35750             0
#
#    jumlah  subtotal   thn tgl_checkout
# 0       1     95000  2019     1/1/2019
# 1       1     80000  2019     1/1/2019
# 2       1     80000  2019     1/1/2019
# 3       1     80000  2019     1/1/2019
# 4       1     55000  2019     2/1/2019

# %%
df = all_data2[all_data2['invoices'].duplicated(keep=False)]
df['Grouped'] = df.groupby('invoices')['kode'].transform(lambda x: ','.join(x))
df2 = df[['invoices', 'Grouped']].drop_duplicates()
df2.head()
# Out:
# E:\Installed\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     invoices                           Grouped
# 1   0101LBDC                    AR31,AT24,AR28
# 5   0201K3GA  AT51,JGA05,JGA05,AR35,AT51,JGA05
# 11  020167JK                       MH 05,MH 03
# 16  0201722B                        JGA05,KH02
# 18  0201F56D                         AT69,AT69

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df2['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key,value in count.most_common(10):
    print(key, value)
# Out:
# ('AT51', 'AT51') 1841
# ('AT51', 'AT59') 1436
# ('AR17', 'AR17') 1259
# ('AT51', 'AT58') 1221
# ('KH01', 'KH02') 1159
# ('AT59', 'AT59') 1115
# ('AR24', 'AR24') 1106
# ('GA04', 'GA05') 1049
# ('AT34', 'AT34') 1043
# ('AR28', 'AR28') 1024

# %%
product_group = all_data2.groupby('nama_produk')
quantity_ordered = product_group.sum()['jumlah']

fig= plt.figure(figsize=(20,5))
keys = [pair for pair, df in product_group]
plt.bar(keys, quantity_ordered, width = 2)
plt.xticks(keys, rotation='vertical', size=10)
plt.show()

# %%
quantity_ordered.head(50).nlargest(10)
# Out:
# nama_produk
# AMMAR KIDS                     5342
# #ngajiyuk                      1865
# AISYAH                         1827
# AL-AQSA                        1304
# ALI BIN ABI THALIB             1303
# AL-AQSA LENGAN PANJANG          924
# ABU BAKAR ASH-SHIDDIQ (s/m)     872
# ABU BAKAR ASH-SHIDDIQ           776
# ASIYAH                          683
# ABU BAKAR                       648
# Name: jumlah, dtype: int64

# %%
product_group_size = all_data2.groupby('ukuran')
quantity_ordered_size = product_group_size.sum()['jumlah']

fig= plt.figure(figsize=(10,2))
keys = [pair for pair, df in product_group_size]
plt.bar(keys, quantity_ordered_size, width = 0.8)
plt.xticks(keys, rotation='vertical', size=10)
plt.show()
